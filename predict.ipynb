# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# 2024-11-03 18:08:57.615439: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-03 18:08:57.637540: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-03 18:08:57.637584: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-03 18:08:57.651355: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from trainer.predict import inference

# %% [markdown]
# # BC Dataset

# %%
inference(
    test_dir="data/BC/test_data/",
    model_paths = ["saved_models/bc_unet3d.keras", 
                   "saved_models/bc_attentionunet3d.keras",
                   "saved_models/bc_augmented_unet3d.keras", 
                   "saved_models/bc_augmented_attentionunet3d.keras",
                  ],
    model_names = ["unet3d",
                   "attentionunet3d", 
                   "unet3d + augmentation", 
                   "attentionunet3d + augmentation",
                  ],
    violin_plot_filename = "bc_dataset_inference",
    dataset_name = "bc",
    patch_shape = (64, 64, 64),
    patch_step = 64
)
# Out:
# Processing img3 image and mask
# 2024-11-03 18:09:04.002093: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38380 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0
# 2024-11-03 18:09:04.003764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38380 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:bd:00.0, compute capability: 8.0
# 2024-11-03 18:09:11.108770: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 13s 128ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 193ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Current Patch: ', max=1055), In…
# ...

# %% [markdown]
# # Sinusoid Dataset

# %%
inference(
    test_dir="data/Sinusoids/test_data/",
    model_paths = ["saved_models/sinusoids_unet3d.keras", 
                   "saved_models/sinusoids_attentionunet3d.keras",
                   "saved_models/sinusoids_augmented_unet3d.keras", 
                   "saved_models/sinusoids_augmented_attentionunet3d.keras",
                  ],
    model_names = ["unet3d",
                   "attentionunet3d", 
                   "unet3d + augmentation", 
                   "attentionunet3d + augmentation",
                  ],
    violin_plot_filename = "sinusoids_dataset_inference",
    dataset_name="sinusoids",
    patch_shape = (64, 64, 64),
    patch_step = 64
)
# Out:
# Processing img3 image and mask
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Current Patch: ', max=1055), In…
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Current Image: ', max=0), Outpu…
